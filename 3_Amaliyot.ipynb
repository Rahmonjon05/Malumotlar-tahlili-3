# %%
#Pandas kutubxonasi bilan csv fayliga murojat
import pandas as pd
csv=pd.read_csv('/content/world_population.csv')
csv
# Out:
#     Rank CCA3  Country/Territory           Capital Continent  2022 Population  \
# 0     36  AFG        Afghanistan             Kabul      Asia       41128771.0
# 1    138  ALB            Albania            Tirana    Europe        2842321.0
# 2     34  DZA            Algeria           Algiers    Africa       44903225.0
# 3    213  ASM     American Samoa         Pago Pago   Oceania          44273.0
# 4    203  AND            Andorra  Andorra la Vella    Europe          79824.0
# ..   ...  ...                ...               ...       ...              ...
# 229  226  WLF  Wallis and Futuna          Mata-Utu   Oceania          11572.0
# 230  172  ESH     Western Sahara          El Aaiún    Africa         575986.0
# 231   46  YEM              Yemen             Sanaa      Asia       33696614.0
# 232   63  ZMB             Zambia            Lusaka    Africa       20017675.0
# 233   74  ZWE           Zimbabwe            Harare    Africa       16320537.0
#
# ...

# %%
from google.colab import files
fayl_yuklash=files.upload()
# Out:
#      <input type="file" id="files-12e83340-1ead-421a-a708-d82e1a541de6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-12e83340-1ead-421a-a708-d82e1a541de6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#jadval boshidagi n ta strga murojat
csv.head(10)
# Out:
#   Rank CCA3    Country/Territory           Capital      Continent  \
# 0   36  AFG          Afghanistan             Kabul           Asia
# 1  138  ALB              Albania            Tirana         Europe
# 2   34  DZA              Algeria           Algiers         Africa
# 3  213  ASM       American Samoa         Pago Pago        Oceania
# 4  203  AND              Andorra  Andorra la Vella         Europe
# 5   42  AGO               Angola            Luanda         Africa
# 6  224  AIA             Anguilla        The Valley  North America
# 7  201  ATG  Antigua and Barbuda      Saint John’s  North America
# 8   33  ARG            Argentina      Buenos Aires  South America
# 9  140  ARM              Armenia           Yerevan           Asia
#
#    2022 Population  2020 Population  2015 Population  2010 Population  \
# 0       41128771.0       38972230.0       33753499.0       28189672.0
# 1        2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
#ustun nomlarini o'zgartirish
csv.rename(columns={'Capital':'Poytaxt','Continent':"Qit'a",'Country/Territory':'Davlat/Maydon'})
# Out:
#     Rank CCA3      Davlat/Maydon           Poytaxt    Qit'a  2022 Population  \
# 0     36  AFG        Afghanistan             Kabul     Asia       41128771.0
# 1    138  ALB            Albania            Tirana   Europe        2842321.0
# 2     34  DZA            Algeria           Algiers   Africa       44903225.0
# 3    213  ASM     American Samoa         Pago Pago  Oceania          44273.0
# 4    203  AND            Andorra  Andorra la Vella   Europe          79824.0
# ..   ...  ...                ...               ...      ...              ...
# 229  226  WLF  Wallis and Futuna          Mata-Utu  Oceania          11572.0
# 230  172  ESH     Western Sahara          El Aaiún   Africa         575986.0
# 231   46  YEM              Yemen             Sanaa     Asia       33696614.0
# 232   63  ZMB             Zambia            Lusaka   Africa       20017675.0
# 233   74  ZWE           Zimbabwe            Harare   Africa       16320537.0
#
# ...

# %%
#csv jadvaldan ustuni ajratib olish
c1=csv['Capital']
c1
# Out:
# 0                 Kabul
# 1                Tirana
# 2               Algiers
# 3             Pago Pago
# 4      Andorra la Vella
#              ...
# 229            Mata-Utu
# 230            El Aaiún
# 231               Sanaa
# 232              Lusaka
# 233              Harare
# Name: Capital, Length: 234, dtype: object

# %%
 #yangi c2 ustunni ajratish
c2=csv['Area (km²)']
c2
# Out:
# 0       652230.0
# 1        28748.0
# 2      2381741.0
# 3          199.0
# 4          468.0
#          ...
# 229        142.0
# 230     266000.0
# 231     527968.0
# 232     752612.0
# 233     390757.0
# Name: Area (km²), Length: 234, dtype: float64

# %%
#jadvallarni birlashtirish
c3=pd.concat([c1,c2])
c3
# Out:
# 0                 Kabul
# 1                Tirana
# 2               Algiers
# 3             Pago Pago
# 4      Andorra la Vella
#              ...
# 229               142.0
# 230            266000.0
# 231            527968.0
# 232            752612.0
# 233            390757.0
# Length: 468, dtype: object

# %%
#satr indexsi bo'yicha murojat
csv.iloc[10:100:10]
# Out:
#    Rank CCA3 Country/Territory      Capital      Continent  2022 Population  \
# 10  198  ABW             Aruba   Oranjestad  North America         106445.0
# 20  177  BLZ            Belize     Belmopan  North America         405272.0
# 30  108  BGR          Bulgaria        Sofia         Europe        6781953.0
# 40   65  CHL             Chile     Santiago  South America       19603733.0
# 50   88  CZE    Czech Republic       Prague         Europe       10493986.0
# 60  132  ERI           Eritrea       Asmara         Africa        3684032.0
# 70  183  PYF  French Polynesia      Papeete        Oceania         306279.0
# 80  178  GLP        Guadeloupe  Basse-Terre  North America         395752.0
# 90   94  HUN           Hungary     Budapest         Europe        9967308.0
#
#     2020 Population  2015 Population  2010 Population  2000 Population  \
# 10         106585.0         104257.0         100341.0          89101.0
# ...

# %%
#satr indexsi bo'yicha murojat
csv.iloc[100]
# Out:
# Rank                                     52
# CCA3                                    CIV
# Country/Territory               Ivory Coast
# Capital                        Yamoussoukro
# Continent                            Africa
# 2022 Population                  28160542.0
# 2020 Population                  26811790.0
# 2015 Population                  23596741.0
# 2010 Population                  21120042.0
# 2000 Population                  16799670.0
# 1990 Population                  11910540.0
# 1980 Population                   8303809.0
# 1970 Population                   5477086.0
# Area (km²)                         322463.0
# Density (per km²)                   87.3295
# Growth Rate                          1.0248
# World Population Percentage            0.35
# Name: 100, dtype: object

# %%
# Satr va ustunga murojat
csv.loc[2,'Capital']
# Out:
# 'Algiers'
